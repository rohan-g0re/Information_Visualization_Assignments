# %% [markdown]
# ## Assignment: Box Office Winner
#
# In this assignment, your task is to reverse engineer a provided visualization from raw data. Specifically, we will visualize the daily box office winners in 2023. The raw data comes from [BoxOfficeMojo](https://www.boxofficemojo.com/daily/2023/?view=year). The target visualization is the following.
#
# ![Box Office Winner 2023](https://github.com/qnzhou/practical_data_visualization_in_python/assets/3606672/f404debd-b1bf-4a98-933e-d3b27e3b3921)
#
# Our temporal axis, spanning from January 1st, 2023 to December 31st, 2023, is represented along the X-axis. Meanwhile, the Y-axis delineates the daily top release for each day. We employ rounded bars to visually signify the duration of a release's dominance at the box office. Each top release is distinguished by a unique color, accompanied by its title displayed preceding the corresponding bar. These releases are organized chronologically, following the order of their initial ascent to the top position.

# %%
import altair as alt
import pandas as pd

url = "https://github.com/qnzhou/practical_data_visualization_in_python/files/14239903/box_office_2023.csv"
df = pd.read_csv(url)

# %%
# Your code here...
df.describe
# Out:
# <bound method NDFrame.describe of             Date         Holiday Day of Week  Top 10 Gross  \
# 0    Dec 31 2023  New Year's Eve      Sunday      23078184
# 1    Dec 30 2023             NaN    Saturday      40050370
# 2    Dec 29 2023             NaN      Friday      37348409
# 3    Dec 28 2023             NaN    Thursday      33261609
# 4    Dec 27 2023             NaN   Wednesday      33892628
# ..           ...             ...         ...           ...
# 360   Jan 5 2023             NaN    Thursday      10864987
# 361   Jan 4 2023             NaN   Wednesday      12131291
# 362   Jan 3 2023             NaN     Tuesday      16965068
# 363   Jan 2 2023             NaN      Monday      32548656
# 364   Jan 1 2023  New Year's Day      Sunday      36210982
#
#      Number of Releases               Top Release     Gross
# 0                    40                     Wonka   5208897
# 1                    41                     Wonka   8637841
# 2                    41                     Wonka   8630268
# 3                    43                     Wonka   7988504
# 4                    42                     Wonka   8135639
# ..                  ...                       ...       ...
# 360                  30  Avatar: The Way of Water   6830651
# 361                  30  Avatar: The Way of Water   7475308
# 362                  31  Avatar: The Way of Water  10544729
# 363                  30  Avatar: The Way of Water  21411622
# 364                  31  Avatar: The Way of Water  24519161
#
# [365 rows x 7 columns]>

# %%
df.head(10)
# Out:
#           Date         Holiday Day of Week  Top 10 Gross  Number of Releases  \
# 0  Dec 31 2023  New Year's Eve      Sunday      23078184                  40
# 1  Dec 30 2023             NaN    Saturday      40050370                  41
# 2  Dec 29 2023             NaN      Friday      37348409                  41
# 3  Dec 28 2023             NaN    Thursday      33261609                  43
# 4  Dec 27 2023             NaN   Wednesday      33892628                  42
# 5  Dec 26 2023             NaN     Tuesday      41788862                  42
# 6  Dec 25 2023   Christmas Day      Monday      58545776                  41
# 7  Dec 24 2023             NaN      Sunday      17021324                  37
# 8  Dec 23 2023             NaN    Saturday      29021089                  38
# 9  Dec 22 2023             NaN      Friday      39891139                  38
#
#                     Top Release     Gross
# 0                         Wonka   5208897
# 1                         Wonka   8637841
# 2                         Wonka   8630268
# 3                         Wonka   7988504
# 4                         Wonka   8135639
# 5                         Wonka   8970413
# 6              The Color Purple  18151050
# 7  Aquaman and the Lost Kingdom   5001421
# 8  Aquaman and the Lost Kingdom   9003036
# 9  Aquaman and the Lost Kingdom  13681754

# %%
df.dtypes
# Out:
# Date                  object
# Holiday               object
# Day of Week           object
# Top 10 Gross           int64
# Number of Releases     int64
# Top Release           object
# Gross                  int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df.columns
# Out:
# Index(['Date', 'Holiday', 'Day of Week', 'Top 10 Gross', 'Number of Releases',
#        'Top Release', 'Gross'],
#       dtype='object')

# %% [markdown]
# # --

# %%
df.head(15)
# Out:
#          Date         Holiday Day of Week  Top 10 Gross  Number of Releases  \
# 0  2023-12-31  New Year's Eve      Sunday      23078184                  40
# 1  2023-12-30             NaN    Saturday      40050370                  41
# 2  2023-12-29             NaN      Friday      37348409                  41
# 3  2023-12-28             NaN    Thursday      33261609                  43
# 4  2023-12-27             NaN   Wednesday      33892628                  42
# 5  2023-12-26             NaN     Tuesday      41788862                  42
# 6  2023-12-25   Christmas Day      Monday      58545776                  41
# 7  2023-12-24             NaN      Sunday      17021324                  37
# 8  2023-12-23             NaN    Saturday      29021089                  38
# 9  2023-12-22             NaN      Friday      39891139                  38
# 10 2023-12-21             NaN    Thursday      12403930                  74
# 11 2023-12-20             NaN   Wednesday       9643216                  38
# 12 2023-12-19             NaN     Tuesday      11609957                  37
# 13 2023-12-18             NaN      Monday       8274749                  37
# 14 2023-12-17             NaN      Sunday      20231817                  38
#
#                      Top Release     Gross
# 0                          Wonka   5208897
# 1                          Wonka   8637841
# 2                          Wonka   8630268
# 3                          Wonka   7988504
# 4                          Wonka   8135639
# 5                          Wonka   8970413
# 6               The Color Purple  18151050
# 7   Aquaman and the Lost Kingdom   5001421
# 8   Aquaman and the Lost Kingdom   9003036
# 9   Aquaman and the Lost Kingdom  13681754
# 10                         Wonka   4201613
# 11                         Wonka   4387803
# 12                         Wonka   5904173
# 13                         Wonka   4003328
# 14                         Wonka  10567353

# %%
# extra column to see  the changes in "Top Release"
df['prev_top_release'] = df['Top Release'].shift(1)
df['consecutive'] = df['Top Release'] == df['prev_top_release']

# make a group identifier for consecuutive ranges
df['group'] = (~df['consecutive']).cumsum()




# find starting and ending of the streak
grouped_df = df.groupby(['group', 'Top Release']).agg(
    start_date=('Date', 'min'),
    end_date=('Date', 'max')
).reset_index()

# %%
# df[df["consecutive"] == False].tail(15)

# %%
# VERY IMP --> Adjusting end_date as the movies with only one day streak are not shown on the plott
grouped_df.loc[grouped_df['start_date'] == grouped_df['end_date'], 'end_date'] += pd.Timedelta(days=1)

# %%
# firstoccurrence  frame for printing the nameonly once in the plot 
first_occurrence = grouped_df.groupby('Top Release').agg(
    first_start=('start_date', 'min')
).reset_index()


sorted_movies = first_occurrence.sort_values('first_start')['Top Release'].tolist()

# %%
df.tail(20)
# Out:
#           Date         Holiday Day of Week  Top 10 Gross  Number of Releases  \
# 345 2023-01-20             NaN      Friday      19736410                  37
# 346 2023-01-19             NaN    Thursday       6634282                  31
# 347 2023-01-18             NaN   Wednesday       6203124                  31
# 348 2023-01-17             NaN     Tuesday       9757114                  31
# 349 2023-01-16         MLK Day      Monday      21069765                  32
# 350 2023-01-15             NaN      Sunday      32575322                  32
# 351 2023-01-14             NaN    Saturday      40457653                  32
# 352 2023-01-13             NaN      Friday      25676736                  33
# 353 2023-01-12             NaN    Thursday       7202303                  30
# 354 2023-01-11             NaN   Wednesday       7964902                  30
# 355 2023-01-10             NaN     Tuesday      10870334                  27
# 356 2023-01-09             NaN      Monday       7924065                  28
# 357 2023-01-08             NaN      Sunday      28588281                  29
# 358 2023-01-07             NaN    Saturday      44649143                  29
# 359 2023-01-06             NaN      Friday      31029606                  29
# 360 2023-01-05             NaN    Thursday      10864987                  30
# 361 2023-01-04             NaN   Wednesday      12131291                  30
# 362 2023-01-03             NaN     Tuesday      16965068                  31
# 363 2023-01-02             NaN      Monday      32548656                  30
# 364 2023-01-01  New Year's Day      Sunday      36210982                  31
#
#                   Top Release     Gross          prev_top_release  \
# 345  Avatar: The Way of Water   4671161  Avatar: The Way of Water
# 346  Avatar: The Way of Water   1959746  Avatar: The Way of Water
# 347  Avatar: The Way of Water   1865293  Avatar: The Way of Water
# 348  Avatar: The Way of Water   2769211  Avatar: The Way of Water
# 349  Avatar: The Way of Water   7056071  Avatar: The Way of Water
# 350  Avatar: The Way of Water  11727060  Avatar: The Way of Water
# 351  Avatar: The Way of Water  14054064  Avatar: The Way of Water
# 352  Avatar: The Way of Water   7043560  Avatar: The Way of Water
# 353  Avatar: The Way of Water   2974300  Avatar: The Way of Water
# 354  Avatar: The Way of Water   3173055  Avatar: The Way of Water
# 355  Avatar: The Way of Water   4547214  Avatar: The Way of Water
# 356  Avatar: The Way of Water   3478414  Avatar: The Way of Water
# 357  Avatar: The Way of Water  13729301  Avatar: The Way of Water
# 358  Avatar: The Way of Water  20688606  Avatar: The Way of Water
# 359                     M3GAN  11726555  Avatar: The Way of Water
# 360  Avatar: The Way of Water   6830651                     M3GAN
# 361  Avatar: The Way of Water   7475308  Avatar: The Way of Water
# 362  Avatar: The Way of Water  10544729  Avatar: The Way of Water
# 363  Avatar: The Way of Water  21411622  Avatar: The Way of Water
# 364  Avatar: The Way of Water  24519161  Avatar: The Way of Water
#
#      consecutive  group
# 345         True     81
# 346         True     81
# 347         True     81
# 348         True     81
# 349         True     81
# 350         True     81
# 351         True     81
# 352         True     81
# 353         True     81
# 354         True     81
# 355         True     81
# 356         True     81
# 357         True     81
# 358         True     81
# 359        False     82
# 360        False     83
# 361         True     83
# 362         True     83
# 363         True     83
# 364         True     83

# %%
sorted_movies
# Out:
# ['Avatar: The Way of Water',
#  'M3GAN',
#  'Pathaan',
#  'The Chosen Season 3 Finale',
#  'Knock at the Cabin',
#  '80 for Brady',
#  "Magic Mike's Last Dance",
#  'Ant-Man and the Wasp: Quantumania',
#  'Cocaine Bear',
#  'Creed III',
#  'Scream VI',
#  'Shazam! Fury of the Gods',
#  'John Wick: Chapter 4',
#  'Dungeons & Dragons: Honor Among Thieves',
#  'The Super Mario Bros. Movie',
#  'Guardians of the Galaxy Vol. 3',
#  'Fast X',
#  'The Little Mermaid',
#  'Spider-Man: Across the Spider-Verse',
#  'Transformers: Rise of the Beasts',
#  'The Flash',
#  'Elemental',
#  'No Hard Feelings',
#  'Indiana Jones and the Dial of Destiny',
#  'Sound of Freedom',
#  'Insidious: The Red Door',
#  'Mission: Impossible - Dead Reckoning Part One',
#  'Barbie',
#  'Blue Beetle',
#  'Gran Turismo',
#  'The Equalizer 3',
#  'The Nun II',
#  'A Haunting in Venice',
#  'Expend4bles',
#  'The Blind',
#  'Saw X',
#  'PAW Patrol: The Mighty Movie',
#  'The Exorcist: Believer',
#  'Taylor Swift: The Eras Tour',
#  'Killers of the Flower Moon',
#  "Five Nights at Freddy's",
#  'The Marvels',
#  'The Hunger Games: The Ballad of Songbirds & Snakes',
#  'Wish',
#  'Renaissance: A Film by Beyoncé',
#  'Godzilla Minus One',
#  'The Boy and the Heron',
#  'Wonka',
#  'Aquaman and the Lost Kingdom',
#  'The Color Purple']

# %%
grouped_df.head(40)
# Out:
#     group                                        Top Release start_date  \
# 0       1                                              Wonka 2023-12-26
# 1       2                                   The Color Purple 2023-12-25
# 2       3                       Aquaman and the Lost Kingdom 2023-12-22
# 3       4                                              Wonka 2023-12-15
# 4       5                              The Boy and the Heron 2023-12-08
# 5       6                                 Godzilla Minus One 2023-12-06
# 6       7  The Hunger Games: The Ballad of Songbirds & Sn... 2023-12-05
# 7       8                                 Godzilla Minus One 2023-12-04
# 8       9                     Renaissance: A Film by Beyoncé 2023-12-03
# 9      10  The Hunger Games: The Ballad of Songbirds & Sn... 2023-12-02
# 10     11                     Renaissance: A Film by Beyoncé 2023-12-01
# 11     12  The Hunger Games: The Ballad of Songbirds & Sn... 2023-11-23
# 12     13                                               Wish 2023-11-22
# 13     14  The Hunger Games: The Ballad of Songbirds & Sn... 2023-11-17
# 14     15                                        The Marvels 2023-11-10
# 15     16                            Five Nights at Freddy's 2023-10-27
# 16     17                        Taylor Swift: The Eras Tour 2023-10-26
# 17     18                         Killers of the Flower Moon 2023-10-23
# 18     19                        Taylor Swift: The Eras Tour 2023-10-19
# 19     20                             The Exorcist: Believer 2023-10-16
# 20     21                        Taylor Swift: The Eras Tour 2023-10-13
# 21     22                             The Exorcist: Believer 2023-10-06
# 22     23                                              Saw X 2023-10-02
# 23     24                       PAW Patrol: The Mighty Movie 2023-09-30
# 24     25                                              Saw X 2023-09-29
# 25     26                                          The Blind 2023-09-28
# 26     27                                         The Nun II 2023-09-27
# 27     28                                        Expend4bles 2023-09-26
# 28     29                                         The Nun II 2023-09-23
# 29     30                                        Expend4bles 2023-09-22
# 30     31                                         The Nun II 2023-09-21
# 31     32                               A Haunting in Venice 2023-09-18
# 32     33                                         The Nun II 2023-09-16
# 33     34                               A Haunting in Venice 2023-09-15
# 34     35                                         The Nun II 2023-09-08
# 35     36                                    The Equalizer 3 2023-09-01
# 36     37                                             Barbie 2023-08-26
# 37     38                                       Gran Turismo 2023-08-25
# 38     39                                             Barbie 2023-08-21
# 39     40                                        Blue Beetle 2023-08-18
#
#      end_date
# 0  2023-12-31
# 1  2023-12-26
# 2  2023-12-24
# 3  2023-12-21
# 4  2023-12-14
# 5  2023-12-07
# 6  2023-12-06
# 7  2023-12-05
# 8  2023-12-04
# 9  2023-12-03
# 10 2023-12-02
# 11 2023-11-30
# 12 2023-11-23
# 13 2023-11-21
# 14 2023-11-16
# 15 2023-11-09
# 16 2023-10-27
# 17 2023-10-25
# 18 2023-10-22
# 19 2023-10-18
# 20 2023-10-15
# 21 2023-10-12
# 22 2023-10-05
# 23 2023-10-01
# 24 2023-09-30
# 25 2023-09-29
# 26 2023-09-28
# 27 2023-09-27
# 28 2023-09-25
# 29 2023-09-23
# 30 2023-09-22
# 31 2023-09-20
# 32 2023-09-17
# 33 2023-09-16
# 34 2023-09-14
# 35 2023-09-07
# 36 2023-08-31
# 37 2023-08-26
# 38 2023-08-24
# 39 2023-08-20

# %% [markdown]
# # Create Gantt Chart

# %%
# Create the Gantt chart with merged bars
chart = alt.Chart(grouped_df).mark_bar(cornerRadius=1).encode(
    x=alt.X('yearmonthdate(start_date):T', title='Date', axis=alt.Axis(orient='top', format='%B')),  # Show months only --> datetime format "%B"
    x2='yearmonthdate(end_date):T',
    y=alt.Y('Top Release:N', sort=sorted_movies, axis=None),  # Sort based on the first occurrence
    color=alt.Color('Top Release:N', legend=None)  # FOR Removing the legend
).properties(
    # title='Box Office Winners: Daily Top Release in 2023',
    width=1000,
    height=696
)

chart
# Out:
# alt.Chart(...)

# %%
# # previous

# chart = alt.Chart(df).mark_bar(cornerRadius=103).encode(
#     x=alt.X('yearmonthdate(Date):T', title='Date', axis=alt.Axis(orient='top', format='%B')),
#     y=alt.Y('Top Release:N',
#             sort=alt.EncodingSortField(field="Date", order='ascending'),
#             axis=None),  # Remove axis to match your goal
#     # color='Top Release:N'
#     color=alt.Color('Top Release:N', legend=None)
# ).properties(
#     title='Box Office Winners: Daily Top Release in 2023',
#     width=1000,
#     height=500
# )

# chart

# %%
# text = alt.Chart(df_with_first).mark_text(
#     align='right',
#     baseline='middle',
#     dx=-5  # Position the text 5 units to the left
# )

# %% [markdown]
# ## Plot having Movie Names at locations of first occurences only

# %%
text = alt.Chart(first_occurrence).mark_text(
    align='right',
    baseline='middle',
    dx=-5  # Position the text 5 units to the left of the start date
).encode(
    x=alt.X('yearmonthdate(first_start):T', title=None),  # Text at the first start date only
    y=alt.Y('Top Release:N', sort=sorted_movies, axis=None),  # Sort based on the first occurrence
    text='Top Release:N',
    color=alt.Color('Top Release:N', legend=None)  # Remove legend
)

text
# Out:
# alt.Chart(...)

# %% [markdown]
# # Ploting Titles

# %%
title_text1 = alt.Chart(pd.DataFrame({'x': [0.5], 'y': [0.5]})).mark_text(
    text='Box Office Winners',
    align='center',
    baseline='middle',
    fontSize=30,
    fontWeight='bold',
    color='black'
).encode(
    x=alt.value(600),  # Adjust x position inside the chart
    y=alt.value(100)   # Adjust y position inside the chart
)
title_text1
# Out:
# alt.Chart(...)

# %%
title_text2 = alt.Chart(pd.DataFrame({'x': [0.5], 'y': [0.5]})).mark_text(
    text='Daily Top Release in 2023',
    align='center',
    baseline='middle',
    fontSize=15,
    color='grey'
).encode(
    x=alt.value(600),  # Adjust x position inside the chart
    y=alt.value(120)   # Adjust y position inside the chart
)
title_text2
# Out:
# alt.Chart(...)

# %%
final_chart = chart + text + title_text1 + title_text2

final_chart
# Out:
# alt.LayerChart(...)

# %%
print("GG")
# Out:
# GG
